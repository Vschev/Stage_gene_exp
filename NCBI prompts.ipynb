# %% [markdown]
# # Simple retrieval from genenames.org (better not to use, its non-exhaustive)

# %%
import requests

genes = ['ESR1', 'PGR', 'GATA3', 'TFF1', 'ESR2', 'ERBB4', 'FOXC1', 'MLPH', 'MAPT', 'SLC39A6',
    'NAT1', 'SLC7A5', 'ABCC4', 'BCL2', 'CCNB1', 'MYBL2', 'FOXM1', 'AURKA', 'CDC20', 'EXO1',
    'MELK', 'BIRC5', 'UBE2C', 'KIF2C', 'RRM2', 'TYMS', 'MMP11', 'ERBB2', 'GRB7', 'HER2',
    'LAPTM4B', 'STAT1', 'MIA', 'CTHRC1', 'CK5', 'EGFR', 'KRT17', 'KRT14', 'KRT6A', 'KRT6B',
    'KRT16', 'CDH3', 'CDH1', 'FOXA1', 'SCUBE2', 'SFRP1', 'AREG', 'TGFB1', 'NME1', 'NME2']

def get_alternative_names(gene):
    # Create the URL for the HGNC API
    url = f'https://www.genenames.org/cgi-bin/download/custom?col=gd_app_sym&col=gd_aliases&status=Approved&hgnc_dbtag=on&order_by=gd_app_sym_sort&format=text&submit=submit&custom_sort=gd_app_sym'

    # Send a GET request to the API
    response = requests.get(url)

    # Split the response text into lines
    lines = response.text.split('\n')

    # Find the gene in the lines and extract the alternative names
    for line in lines:
        if line.startswith(gene + '\t'):
            data = line.split('\t')
            alternative_names = data[1].split('|')
            return alternative_names

    return []

my_genes = {}
for gene in genes:
    alternative_names = get_alternative_names(gene)
    if alternative_names:
        my_genes[gene] = alternative_names

for i in my_genes:
    print(i, my_genes[i])
# Out:
# ESR1
# PGR
# GATA3
# TFF1
# ESR2
# ERBB4
# FOXC1
# MLPH
# MAPT
# SLC39A6
# NAT1
# SLC7A5
# ABCC4
# BCL2
# CCNB1
# MYBL2
# FOXM1
# AURKA
# CDC20
# EXO1
# MELK
# BIRC5
# UBE2C
# KIF2C
# RRM2
# TYMS
# MMP11
# ERBB2
# GRB7
# LAPTM4B
# STAT1
# MIA
# CTHRC1
# EGFR
# KRT17
# KRT14
# KRT6A
# KRT6B
# KRT16
# CDH3
# CDH1
# FOXA1
# SCUBE2
# SFRP1
# AREG
# TGFB1
# NME1
# NME2

# %% [markdown]
# # Retrieve IDs from NCBI for the list of genes

# %%
import requests
from bs4 import BeautifulSoup

pam50_gene_list = ['ESR1', 'ERBB2', 'PGR', 'MKI67', 'CCNB1', 'MYBL2', 'CDC20', 'UBE2C', 'BIRC5', 'ANLN', 'KRT5', 'EGFR', 'FOXA1', 'GRB7', 'ERBB3', 'MELK', 'NDC80', 'TMEM45B', 'ACTR3B', 'CDCA1', 'RAD51AP1', 'UBE2T', 'RRM2', 'AURKA', 'EXO1', 'TOP2A', 'FOXM1', 'MLPH', 'GLI2', 'CDC6', 'KIF2C', 'GSTM1', 'TYMS', 'MMP11', 'MIA', 'MMP9', 'CCNE1', 'JUNB', 'MAPT', 'CENPF', 'GPR160', 'RABEP1', 'PSRC1', 'SPAG5', 'MAFB', 'PGRMC1', 'GRB14', 'CXXC5', 'LIMCH1']

def get_gene_id(gene_name):
    url = f'https://www.ncbi.nlm.nih.gov/gene/?term={gene_name}+Homo+sapiens'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    gene_link = soup.find('a', text=gene_name)
    if gene_link:
        gene_id = gene_link.get('href').split('/')[-1]
        return gene_id
    else:
        return None

gene_ids = {}

for gene_name in pam50_gene_list:
    gene_id = get_gene_id(gene_name)
    gene_ids[gene_name] = gene_id

for gene_name, gene_id in gene_ids.items():
    print(f'Gene Name: {gene_name}, Gene ID: {gene_id}')
# Out:
# Gene Name: ESR1, Gene ID: 2099
# Gene Name: ERBB2, Gene ID: 2064
# Gene Name: PGR, Gene ID: 5241
# Gene Name: MKI67, Gene ID: 4288
# Gene Name: CCNB1, Gene ID: 891
# Gene Name: MYBL2, Gene ID: 4605
# Gene Name: CDC20, Gene ID: 991
# Gene Name: UBE2C, Gene ID: 11065
# Gene Name: BIRC5, Gene ID: 332
# Gene Name: ANLN, Gene ID: 54443
# Gene Name: KRT5, Gene ID: 3852
# Gene Name: EGFR, Gene ID: 1956
# Gene Name: FOXA1, Gene ID: 3169
# Gene Name: GRB7, Gene ID: 2886
# Gene Name: ERBB3, Gene ID: 2065
# Gene Name: MELK, Gene ID: 9833
# Gene Name: NDC80, Gene ID: 10403
# Gene Name: TMEM45B, Gene ID: 120224
# Gene Name: ACTR3B, Gene ID: 57180
# Gene Name: CDCA1, Gene ID: None
# Gene Name: RAD51AP1, Gene ID: 10635
# Gene Name: UBE2T, Gene ID: 29089
# Gene Name: RRM2, Gene ID: 6241
# Gene Name: AURKA, Gene ID: 6790
# Gene Name: EXO1, Gene ID: 9156
# Gene Name: TOP2A, Gene ID: 7153
# Gene Name: FOXM1, Gene ID: 2305
# Gene Name: MLPH, Gene ID: 79083
# Gene Name: GLI2, Gene ID: 2736
# Gene Name: CDC6, Gene ID: 990
# Gene Name: KIF2C, Gene ID: 11004
# Gene Name: GSTM1, Gene ID: 2944
# Gene Name: TYMS, Gene ID: 7298
# Gene Name: MMP11, Gene ID: 4320
# Gene Name: MIA, Gene ID: 8190
# Gene Name: MMP9, Gene ID: 4318
# Gene Name: CCNE1, Gene ID: 898
# Gene Name: JUNB, Gene ID: 3726
# Gene Name: MAPT, Gene ID: 4137
# Gene Name: CENPF, Gene ID: 1063
# Gene Name: GPR160, Gene ID: 26996
# Gene Name: RABEP1, Gene ID: 9135
# Gene Name: PSRC1, Gene ID: 84722
# Gene Name: SPAG5, Gene ID: 10615
# Gene Name: MAFB, Gene ID: 9935
# Gene Name: PGRMC1, Gene ID: 10857
# Gene Name: GRB14, Gene ID: 2888
# Gene Name: CXXC5, Gene ID: 51523
# Gene Name: LIMCH1, Gene ID: 22998

# %% [markdown]
# # Return all synonims for genes with IDs in the list

# %%
import requests
from bs4 import BeautifulSoup

gene_ids = [2099, 2064, 5241, 4288, 891, 4605, 991, 11065, 332, 54443, 3852, 1956, 3169, 2886, 2065, 9833, 10403, 120224, 57180, 83540, 10635, 29089, 6241, 6790, 9156, 7153, 2305, 79083, 2736, 990, 11004, 2944, 7298, 4320, 8190, 4318, 898, 3726, 4137, 1063, 26996, 9135, 84722, 10615, 9935, 10857, 2888, 51523, 22998]

def get_alternative_names(gene_id):
    url = f"https://www.ncbi.nlm.nih.gov/gene/{gene_id}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    dt_elements = soup.find_all('dt')
    for dt_element in dt_elements:
        if dt_element.text == "Also known as":
            dd_element = dt_element.find_next('dd')
            alternative_names = dd_element.text.split('; ')
            return alternative_names
    return []

my_genes = {}
for gene_id in gene_ids:
    alternative_names = get_alternative_names(gene_id)
    my_genes[gene_id] = alternative_names
    print(f"Gene ID: {gene_id}")
    print(f"Alternative Names: {alternative_names}")
# Out:
# Gene ID: 2099
# Alternative Names: ['ER', 'ESR', 'Era', 'ESRA', 'ESTRR', 'NR3A1']
# Gene ID: 2064
# Alternative Names: ['NEU', 'NGL', 'HER2', 'TKR1', 'CD340', 'HER-2', 'VSCN2', 'MLN 19', 'MLN-19', 'c-ERB2', 'c-ERB-2', 'HER-2/neu', 'p185(erbB2)']
# Gene ID: 5241
# Alternative Names: ['PR', 'NR3C3']
# Gene ID: 4288
# Alternative Names: ['KIA', 'MIB-', 'MIB-1', 'PPP1R105']
# Gene ID: 891
# Alternative Names: ['CCNB']
# Gene ID: 4605
# Alternative Names: ['BMYB', 'B-MYB']
# Gene ID: 991
# Alternative Names: ['CDC20A', 'OOMD14', 'p55CDC', 'OZEMA14', 'bA276H19.3']
# Gene ID: 11065
# Alternative Names: ['UBCH10', 'dJ447F3.2']
# Gene ID: 332
# Alternative Names: ['API4', 'EPR-1']
# Gene ID: 54443
# Alternative Names: ['scra', 'FSGS8', 'Scraps']
# Gene ID: 3852
# Alternative Names: ['K5', 'CK5', 'DDD', 'DDD1', 'EBS1', 'EBS2', 'EBS2A', 'EBS2B', 'EBS2C', 'EBS2D', 'EBS2E', 'EBS2F', 'KRT5A']
# Gene ID: 1956
# Alternative Names: ['ERBB', 'ERRP', 'HER1', 'mENA', 'ERBB1', 'PIG61', 'NISBD2']
# Gene ID: 3169
# Alternative Names: ['HNF3A', 'TCF3A']
# Gene ID: 2886
# Alternative Names: []
# Gene ID: 2065
# Alternative Names: ['HER3', 'FERLK', 'LCCS2', 'VSCN1', 'ErbB-3', 'c-erbB3', 'erbB3-S', 'MDA-BF-1', 'c-erbB-3', 'p180-ErbB3', 'p45-sErbB3', 'p85-sErbB3']
# Gene ID: 9833
# Alternative Names: ['HPK38']
# Gene ID: 10403
# Alternative Names: ['HEC', 'HEC1', 'TID3', 'KNTC2', 'HsHec1', 'hsNDC80']
# Gene ID: 120224
# Alternative Names: []
# Gene ID: 57180
# Alternative Names: ['ARP11', 'ARP3BETA']
# Gene ID: 83540
# Alternative Names: ['CDCA1', 'CT106', 'NUF2R']
# Gene ID: 10635
# Alternative Names: ['PIR51']
# Gene ID: 29089
# Alternative Names: ['FANCT', 'PIG50', 'HSPC150']
# Gene ID: 6241
# Alternative Names: ['R2', 'RR2', 'RR2M', 'C2orf48']
# Gene ID: 6790
# Alternative Names: ['AIK', 'ARK1', 'AURA', 'BTAK', 'STK6', 'STK7', 'STK15', 'PPP1R47']
# Gene ID: 9156
# Alternative Names: ['HEX1', 'hExoI']
# Gene ID: 7153
# Alternative Names: ['TOP2', 'TP2A', 'TOPIIA', 'TOP2alpha']
# Gene ID: 2305
# Alternative Names: ['MPP2', 'HFH11', 'HNF-3', 'INS-1', 'MPP-2', 'PIG29', 'FKHL16', 'FOXM1A', 'FOXM1B', 'FOXM1C', 'HFH-11', 'TRIDENT', 'MPHOSPH2']
# Gene ID: 79083
# Alternative Names: ['SLAC2-A']
# Gene ID: 2736
# Alternative Names: ['CJS', 'HPE9', 'PHS2', 'THP1', 'THP2']
# Gene ID: 990
# Alternative Names: ['CDC18L', 'HsCDC6', 'MGORS5', 'HsCDC18']
# Gene ID: 11004
# Alternative Names: ['MCAK', 'CT139', 'KNSL6']
# Gene ID: 2944
# Alternative Names: ['MU', 'H-B', 'GST1', 'GTH4', 'GTM1', 'MU-1', 'GSTM1-1', 'GSTM1a-1a', 'GSTM1b-1b']
# Gene ID: 7298
# Alternative Names: ['TS', 'TMS', 'DKCD', 'HST422']
# Gene ID: 4320
# Alternative Names: ['ST3', 'SL-3', 'STMY3']
# Gene ID: 8190
# Alternative Names: ['MIA1', 'CD-RAP']
# Gene ID: 4318
# Alternative Names: ['GELB', 'CLG4B', 'MMP-9', 'MANDP2']
# Gene ID: 898
# Alternative Names: ['CCNE', 'pCCNE1']
# Gene ID: 3726
# Alternative Names: ['AP-1']
# Gene ID: 4137
# Alternative Names: ['TAU', 'MSTD', 'PPND', 'DDPAC', 'MAPTL', 'MTBT1', 'MTBT2', 'tau-40', 'FTDP-17', 'PPP1R103', 'Tau-PHF6']
# Gene ID: 1063
# Alternative Names: ['CENF', 'hcp-1', 'CILD31', 'STROMS', 'PRO1779']
# Gene ID: 26996
# Alternative Names: ['GPCR1', 'GPCR150']
# Gene ID: 9135
# Alternative Names: ['RAB5EP', 'RABPT5']
# Gene ID: 84722
# Alternative Names: ['DDA3', 'FP3214']
# Gene ID: 10615
# Alternative Names: ['MAP126', 'DEEPEST', 'hMAP126']
# Gene ID: 9935
# Alternative Names: ['KRML', 'MCTO', 'DURS3']
# Gene ID: 10857
# Alternative Names: ['IZA', 'MPR', 'Dap1', 'HPR6.6']
# Gene ID: 2888
# Alternative Names: []
# Gene ID: 51523
# Alternative Names: ['CF5', 'WID', 'RINF', 'HSPC195']
# Gene ID: 22998
# Alternative Names: ['LMO7B', 'LIMCH1A']

# %%
gene_ids
# Out:
# ['2099',
#  '2064',
#  '207',
#  '3845',
#  '7422',
#  '6416',
#  '672',
#  '4085',
#  '2308',
#  '782',
#  '5241',
#  '673',
#  '4318',
#  '596',
#  '2249',
#  '55904',
#  '9575',
#  '2353',
#  '6256',
#  '5050',
#  '4171',
#  '4193',
#  '7157',
#  '860',
#  '598',
#  '3576',
#  '6732',
#  '6720',
#  '5290',
#  '3417',
#  '6790',
#  '5728',
#  '2202',
#  '4055',
#  '864',
#  '6193',
#  '6233',
#  '6194',
#  '3569',
#  '23411',
#  '9844',
#  '648',
#  '9133',
#  '10891',
#  '8811',
#  '23471',
#  '868',
#  '811',
#  '6159',
#  '4843',
#  '54106']

# %%
genes
# Out:
# ['ESR1',
#  'PGR',
#  'GATA3',
#  'TFF1',
#  'ESR2',
#  'ERBB4',
#  'FOXC1',
#  'MLPH',
#  'MAPT',
#  'SLC39A6',
#  'NAT1',
#  'SLC7A5',
#  'ABCC4',
#  'BCL2',
#  'CCNB1',
#  'MYBL2',
#  'FOXM1',
#  'AURKA',
#  'CDC20',
#  'EXO1',
#  'MELK',
#  'BIRC5',
#  'UBE2C',
#  'KIF2C',
#  'RRM2',
#  'TYMS',
#  'MMP11',
#  'ERBB2',
#  'GRB7',
#  'HER2',
#  'LAPTM4B',
#  'STAT1',
#  'MIA',
#  'CTHRC1',
#  'CK5',
#  'EGFR',
#  'KRT17',
#  'KRT14',
#  'KRT6A',
#  'KRT6B',
#  'KRT16',
#  'CDH3',
#  'CDH1',
#  'FOXA1',
#  'SCUBE2',
#  'SFRP1',
#  'AREG',
#  'TGFB1',
#  'NME1',
#  'NME2']

# %%
my_genes
# Out:
# {2099: ['ER', 'ESR', 'Era', 'ESRA', 'ESTRR', 'NR3A1'],
#  2064: ['NEU',
#   'NGL',
#   'HER2',
#   'TKR1',
#   'CD340',
#   'HER-2',
#   'VSCN2',
#   'MLN 19',
#   'MLN-19',
#   'c-ERB2',
#   'c-ERB-2',
#   'HER-2/neu',
#   'p185(erbB2)'],
#  5241: ['PR', 'NR3C3'],
#  4288: ['KIA', 'MIB-', 'MIB-1', 'PPP1R105'],
#  891: ['CCNB'],
#  4605: ['BMYB', 'B-MYB'],
#  991: ['CDC20A', 'OOMD14', 'p55CDC', 'OZEMA14', 'bA276H19.3'],
#  11065: ['UBCH10', 'dJ447F3.2'],
#  332: ['API4', 'EPR-1'],
#  54443: ['scra', 'FSGS8', 'Scraps'],
#  3852: ['K5',
#   'CK5',
#   'DDD',
#   'DDD1',
#   'EBS1',
#   'EBS2',
#   'EBS2A',
#   'EBS2B',
#   'EBS2C',
#   'EBS2D',
#   'EBS2E',
#   'EBS2F',
#   'KRT5A'],
#  1956: ['ERBB', 'ERRP', 'HER1', 'mENA', 'ERBB1', 'PIG61', 'NISBD2'],
#  3169: ['HNF3A', 'TCF3A'],
#  2886: [],
#  2065: ['HER3',
#   'FERLK',
#   'LCCS2',
#   'VSCN1',
#   'ErbB-3',
#   'c-erbB3',
#   'erbB3-S',
#   'MDA-BF-1',
#   'c-erbB-3',
#   'p180-ErbB3',
#   'p45-sErbB3',
#   'p85-sErbB3'],
#  9833: ['HPK38'],
#  10403: ['HEC', 'HEC1', 'TID3', 'KNTC2', 'HsHec1', 'hsNDC80'],
#  120224: [],
#  57180: ['ARP11', 'ARP3BETA'],
#  83540: ['CDCA1', 'CT106', 'NUF2R'],
#  10635: ['PIR51'],
#  29089: ['FANCT', 'PIG50', 'HSPC150'],
#  6241: ['R2', 'RR2', 'RR2M', 'C2orf48'],
#  6790: ['AIK', 'ARK1', 'AURA', 'BTAK', 'STK6', 'STK7', 'STK15', 'PPP1R47'],
#  9156: ['HEX1', 'hExoI'],
#  7153: ['TOP2', 'TP2A', 'TOPIIA', 'TOP2alpha'],
#  2305: ['MPP2',
#   'HFH11',
#   'HNF-3',
#   'INS-1',
#   'MPP-2',
#   'PIG29',
#   'FKHL16',
#   'FOXM1A',
#   'FOXM1B',
#   'FOXM1C',
#   'HFH-11',
#   'TRIDENT',
#   'MPHOSPH2'],
#  79083: ['SLAC2-A'],
#  2736: ['CJS', 'HPE9', 'PHS2', 'THP1', 'THP2'],
#  990: ['CDC18L', 'HsCDC6', 'MGORS5', 'HsCDC18'],
#  11004: ['MCAK', 'CT139', 'KNSL6'],
#  2944: ['MU',
#   'H-B',
#   'GST1',
#   'GTH4',
#   'GTM1',
#   'MU-1',
#   'GSTM1-1',
#   'GSTM1a-1a',
#   'GSTM1b-1b'],
#  7298: ['TS', 'TMS', 'DKCD', 'HST422'],
#  4320: ['ST3', 'SL-3', 'STMY3'],
#  8190: ['MIA1', 'CD-RAP'],
#  4318: ['GELB', 'CLG4B', 'MMP-9', 'MANDP2'],
#  898: ['CCNE', 'pCCNE1'],
#  3726: ['AP-1'],
#  4137: ['TAU',
#   'MSTD',
#   'PPND',
#   'DDPAC',
#   'MAPTL',
#   'MTBT1',
#   'MTBT2',
#   'tau-40',
#   'FTDP-17',
#   'PPP1R103',
#   'Tau-PHF6'],
#  1063: ['CENF', 'hcp-1', 'CILD31', 'STROMS', 'PRO1779'],
#  26996: ['GPCR1', 'GPCR150'],
#  9135: ['RAB5EP', 'RABPT5'],
#  84722: ['DDA3', 'FP3214'],
#  10615: ['MAP126', 'DEEPEST', 'hMAP126'],
#  9935: ['KRML', 'MCTO', 'DURS3'],
#  10857: ['IZA', 'MPR', 'Dap1', 'HPR6.6'],
#  2888: [],
#  51523: ['CF5', 'WID', 'RINF', 'HSPC195'],
#  22998: ['LMO7B', 'LIMCH1A']}

# %% [markdown]
# # Compiling them all together

# %%
genes_with_synonims = []
for gene in genes:
    genes_with_synonims.append(gene)
for gene_id in my_genes:
    for synonim in my_genes[gene_id]:
        genes_with_synonims.append(synonim)
genes_with_synonims
# Out:
# ['ESR1',
#  'PGR',
#  'GATA3',
#  'TFF1',
#  'ESR2',
#  'ERBB4',
#  'FOXC1',
#  'MLPH',
#  'MAPT',
#  'SLC39A6',
#  'NAT1',
#  'SLC7A5',
#  'ABCC4',
#  'BCL2',
#  'CCNB1',
#  'MYBL2',
#  'FOXM1',
#  'AURKA',
#  'CDC20',
#  'EXO1',
#  'MELK',
#  'BIRC5',
#  'UBE2C',
#  'KIF2C',
#  'RRM2',
#  'TYMS',
#  'MMP11',
#  'ERBB2',
#  'GRB7',
#  'HER2',
#  'LAPTM4B',
#  'STAT1',
#  'MIA',
#  'CTHRC1',
#  'CK5',
#  'EGFR',
#  'KRT17',
#  'KRT14',
#  'KRT6A',
#  'KRT6B',
#  'KRT16',
#  'CDH3',
#  'CDH1',
#  'FOXA1',
#  'SCUBE2',
#  'SFRP1',
#  'AREG',
#  'TGFB1',
#  'NME1',
#  'NME2',
#  'ER',
#  'ESR',
#  'Era',
#  'ESRA',
#  'ESTRR',
#  'NR3A1',
#  'NEU',
#  'NGL',
#  'HER2',
#  'TKR1',
#  'CD340',
#  'HER-2',
#  'VSCN2',
#  'MLN 19',
#  'MLN-19',
#  'c-ERB2',
#  'c-ERB-2',
#  'HER-2/neu',
#  'p185(erbB2)',
#  'PR',
#  'NR3C3',
#  'KIA',
#  'MIB-',
#  'MIB-1',
#  'PPP1R105',
#  'CCNB',
#  'BMYB',
#  'B-MYB',
#  'CDC20A',
#  'OOMD14',
#  'p55CDC',
#  'OZEMA14',
#  'bA276H19.3',
#  'UBCH10',
#  'dJ447F3.2',
#  'API4',
#  'EPR-1',
#  'scra',
#  'FSGS8',
#  'Scraps',
#  'K5',
#  'CK5',
#  'DDD',
#  'DDD1',
#  'EBS1',
#  'EBS2',
#  'EBS2A',
#  'EBS2B',
#  'EBS2C',
#  'EBS2D',
#  'EBS2E',
#  'EBS2F',
#  'KRT5A',
#  'ERBB',
#  'ERRP',
#  'HER1',
#  'mENA',
#  'ERBB1',
#  'PIG61',
#  'NISBD2',
#  'HNF3A',
#  'TCF3A',
#  'HER3',
#  'FERLK',
#  'LCCS2',
#  'VSCN1',
#  'ErbB-3',
#  'c-erbB3',
#  'erbB3-S',
#  'MDA-BF-1',
#  'c-erbB-3',
#  'p180-ErbB3',
#  'p45-sErbB3',
#  'p85-sErbB3',
#  'HPK38',
#  'HEC',
#  'HEC1',
#  'TID3',
#  'KNTC2',
#  'HsHec1',
#  'hsNDC80',
#  'ARP11',
#  'ARP3BETA',
#  'CDCA1',
#  'CT106',
#  'NUF2R',
#  'PIR51',
#  'FANCT',
#  'PIG50',
#  'HSPC150',
#  'R2',
#  'RR2',
#  'RR2M',
#  'C2orf48',
#  'AIK',
#  'ARK1',
#  'AURA',
#  'BTAK',
#  'STK6',
#  'STK7',
#  'STK15',
#  'PPP1R47',
#  'HEX1',
#  'hExoI',
#  'TOP2',
#  'TP2A',
#  'TOPIIA',
#  'TOP2alpha',
#  'MPP2',
#  'HFH11',
#  'HNF-3',
#  'INS-1',
#  'MPP-2',
#  'PIG29',
#  'FKHL16',
#  'FOXM1A',
#  'FOXM1B',
#  'FOXM1C',
#  'HFH-11',
#  'TRIDENT',
#  'MPHOSPH2',
#  'SLAC2-A',
#  'CJS',
#  'HPE9',
#  'PHS2',
#  'THP1',
#  'THP2',
#  'CDC18L',
#  'HsCDC6',
#  'MGORS5',
#  'HsCDC18',
#  'MCAK',
#  'CT139',
#  'KNSL6',
#  'MU',
#  'H-B',
#  'GST1',
#  'GTH4',
#  'GTM1',
#  'MU-1',
#  'GSTM1-1',
#  'GSTM1a-1a',
#  'GSTM1b-1b',
#  'TS',
#  'TMS',
#  'DKCD',
#  'HST422',
#  'ST3',
#  'SL-3',
#  'STMY3',
#  'MIA1',
#  'CD-RAP',
#  'GELB',
#  'CLG4B',
#  'MMP-9',
#  'MANDP2',
#  'CCNE',
#  'pCCNE1',
#  'AP-1',
#  'TAU',
#  'MSTD',
#  'PPND',
#  'DDPAC',
#  'MAPTL',
#  'MTBT1',
#  'MTBT2',
#  'tau-40',
#  'FTDP-17',
#  'PPP1R103',
#  'Tau-PHF6',
#  'CENF',
#  'hcp-1',
#  'CILD31',
#  'STROMS',
#  'PRO1779',
#  'GPCR1',
#  'GPCR150',
#  'RAB5EP',
#  'RABPT5',
#  'DDA3',
#  'FP3214',
#  'MAP126',
#  'DEEPEST',
#  'hMAP126',
#  'KRML',
#  'MCTO',
#  'DURS3',
#  'IZA',
#  'MPR',
#  'Dap1',
#  'HPR6.6',
#  'CF5',
#  'WID',
#  'RINF',
#  'HSPC195',
#  'LMO7B',
#  'LIMCH1A']

# %%
import pandas as pd

anova_results = pd.read_excel("View_pairwise_anova_selected.xlsx")
survival_results = pd.read_excel("View_univariate_survival_analysis_logHR_selected.xlsx")

# %%
anova_markers = []
survival_markers = []
for i in survival_results["Unnamed: 0"]:
    if i in genes_with_synonims:
        survival_markers.append(i)
for i in anova_results["Unnamed: 0"]:
    if i in genes_with_synonims:
        anova_markers.append(i)

# %%
anova_markers
# Out:
# ['CDC20', 'MLPH']

# %%
survival_markers
# Out:
# ['CDC20', 'MLPH']

# %%
genes_with_synonims
# Out:
# ['ESR1',
#  'PGR',
#  'GATA3',
#  'TFF1',
#  'ESR2',
#  'ERBB4',
#  'FOXC1',
#  'MLPH',
#  'MAPT',
#  'SLC39A6',
#  'NAT1',
#  'SLC7A5',
#  'ABCC4',
#  'BCL2',
#  'CCNB1',
#  'MYBL2',
#  'FOXM1',
#  'AURKA',
#  'CDC20',
#  'EXO1',
#  'MELK',
#  'BIRC5',
#  'UBE2C',
#  'KIF2C',
#  'RRM2',
#  'TYMS',
#  'MMP11',
#  'ERBB2',
#  'GRB7',
#  'HER2',
#  'LAPTM4B',
#  'STAT1',
#  'MIA',
#  'CTHRC1',
#  'CK5',
#  'EGFR',
#  'KRT17',
#  'KRT14',
#  'KRT6A',
#  'KRT6B',
#  'KRT16',
#  'CDH3',
#  'CDH1',
#  'FOXA1',
#  'SCUBE2',
#  'SFRP1',
#  'AREG',
#  'TGFB1',
#  'NME1',
#  'NME2',
#  'ER',
#  'ESR',
#  'Era',
#  'ESRA',
#  'ESTRR',
#  'NR3A1',
#  'NEU',
#  'NGL',
#  'HER2',
#  'TKR1',
#  'CD340',
#  'HER-2',
#  'VSCN2',
#  'MLN 19',
#  'MLN-19',
#  'c-ERB2',
#  'c-ERB-2',
#  'HER-2/neu',
#  'p185(erbB2)',
#  'PR',
#  'NR3C3',
#  'KIA',
#  'MIB-',
#  'MIB-1',
#  'PPP1R105',
#  'CCNB',
#  'BMYB',
#  'B-MYB',
#  'CDC20A',
#  'OOMD14',
#  'p55CDC',
#  'OZEMA14',
#  'bA276H19.3',
#  'UBCH10',
#  'dJ447F3.2',
#  'API4',
#  'EPR-1',
#  'scra',
#  'FSGS8',
#  'Scraps',
#  'K5',
#  'CK5',
#  'DDD',
#  'DDD1',
#  'EBS1',
#  'EBS2',
#  'EBS2A',
#  'EBS2B',
#  'EBS2C',
#  'EBS2D',
#  'EBS2E',
#  'EBS2F',
#  'KRT5A',
#  'ERBB',
#  'ERRP',
#  'HER1',
#  'mENA',
#  'ERBB1',
#  'PIG61',
#  'NISBD2',
#  'HNF3A',
#  'TCF3A',
#  'HER3',
#  'FERLK',
#  'LCCS2',
#  'VSCN1',
#  'ErbB-3',
#  'c-erbB3',
#  'erbB3-S',
#  'MDA-BF-1',
#  'c-erbB-3',
#  'p180-ErbB3',
#  'p45-sErbB3',
#  'p85-sErbB3',
#  'HPK38',
#  'HEC',
#  'HEC1',
#  'TID3',
#  'KNTC2',
#  'HsHec1',
#  'hsNDC80',
#  'ARP11',
#  'ARP3BETA',
#  'CDCA1',
#  'CT106',
#  'NUF2R',
#  'PIR51',
#  'FANCT',
#  'PIG50',
#  'HSPC150',
#  'R2',
#  'RR2',
#  'RR2M',
#  'C2orf48',
#  'AIK',
#  'ARK1',
#  'AURA',
#  'BTAK',
#  'STK6',
#  'STK7',
#  'STK15',
#  'PPP1R47',
#  'HEX1',
#  'hExoI',
#  'TOP2',
#  'TP2A',
#  'TOPIIA',
#  'TOP2alpha',
#  'MPP2',
#  'HFH11',
#  'HNF-3',
#  'INS-1',
#  'MPP-2',
#  'PIG29',
#  'FKHL16',
#  'FOXM1A',
#  'FOXM1B',
#  'FOXM1C',
#  'HFH-11',
#  'TRIDENT',
#  'MPHOSPH2',
#  'SLAC2-A',
#  'CJS',
#  'HPE9',
#  'PHS2',
#  'THP1',
#  'THP2',
#  'CDC18L',
#  'HsCDC6',
#  'MGORS5',
#  'HsCDC18',
#  'MCAK',
#  'CT139',
#  'KNSL6',
#  'MU',
#  'H-B',
#  'GST1',
#  'GTH4',
#  'GTM1',
#  'MU-1',
#  'GSTM1-1',
#  'GSTM1a-1a',
#  'GSTM1b-1b',
#  'TS',
#  'TMS',
#  'DKCD',
#  'HST422',
#  'ST3',
#  'SL-3',
#  'STMY3',
#  'MIA1',
#  'CD-RAP',
#  'GELB',
#  'CLG4B',
#  'MMP-9',
#  'MANDP2',
#  'CCNE',
#  'pCCNE1',
#  'AP-1',
#  'TAU',
#  'MSTD',
#  'PPND',
#  'DDPAC',
#  'MAPTL',
#  'MTBT1',
#  'MTBT2',
#  'tau-40',
#  'FTDP-17',
#  'PPP1R103',
#  'Tau-PHF6',
#  'CENF',
#  'hcp-1',
#  'CILD31',
#  'STROMS',
#  'PRO1779',
#  'GPCR1',
#  'GPCR150',
#  'RAB5EP',
#  'RABPT5',
#  'DDA3',
#  'FP3214',
#  'MAP126',
#  'DEEPEST',
#  'hMAP126',
#  'KRML',
#  'MCTO',
#  'DURS3',
#  'IZA',
#  'MPR',
#  'Dap1',
#  'HPR6.6',
#  'CF5',
#  'WID',
#  'RINF',
#  'HSPC195',
#  'LMO7B',
#  'LIMCH1A']

# %%
all_genes = pd.read_excel("all_genes_data_Basal-like+Claudin-low.xlsx")

# %%
all_markers = []
for i in all_genes["gene_name"]:
    if i in genes_with_synonims:
        all_markers.append(i)
all_markers
# Out:
# ['MLPH', 'CDC20']

# %%
import numpy as np
mask = survival_results.notna()

# %%
for x in survival_results['All-tumours']:
    if x == survival_results[mask]:
        print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
#       1 for x in survival_results['All-tumours']:
# ----> 2     if x == survival_results[mask]:
#       3         print(x)
#
# File C:\Anaconda\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
atsurv = []
la = []
lb = []
her2 = []
bl = []
for i in survival_results['Unnamed: 0'][survival_results['All-tumours'].notna()]:
    atsurv.append(i)
for i in survival_results['Unnamed: 0'][survival_results['Luminal-A'].notna()]:
    la.append(i)
for i in survival_results['Unnamed: 0'][survival_results['Luminal-B'].notna()]:
    lb.append(i)
for i in survival_results['Unnamed: 0'][survival_results['HER2-enriched'].notna()]:
    her2.append(i)
for i in survival_results['Unnamed: 0'][survival_results['Basal-like'].notna()]:
    bl.append(i)

# %%
groups = {0: "atsurv", 1: "la", 2: "lb", 3: "her2", 4: "bl"}
for group in range(5):
    for group2 in range(5):
        if group2 > group:
            for gene in [atsurv, la, lb, her2, bl][group]:
                if gene in [atsurv, la, lb, her2, bl][group2]:
                    print(groups[group], groups[group2], gene)
# Out:
# atsurv la MORC4
# atsurv lb MORC4
# atsurv her2 CSKMT
# la lb MORC4
# la lb SMYD4
# la lb WDR88
# la her2 BRPF1
# la her2 CBX5
# la her2 HIF1AN
# la her2 RBSN
# la her2 SETD5
# lb her2 MLPH

# %%
atsurv = []
la = []
lb = []
her2 = []
bl = []
for i in anova_results['Unnamed: 0'][anova_results['All-tumours'].notna()]:
    atsurv.append(i)
for i in anova_results['Unnamed: 0'][anova_results['Luminal-A'].notna()]:
    la.append(i)
for i in anova_results['Unnamed: 0'][anova_results['Luminal-B'].notna()]:
    lb.append(i)
for i in anova_results['Unnamed: 0'][anova_results['HER2-enriched'].notna()]:
    her2.append(i)
for i in anova_results['Unnamed: 0'][anova_results['Basal-like'].notna()]:
    bl.append(i)

# %%
groups = {0: "atsurv", 1: "la", 2: "lb", 3: "her2", 4: "bl"}
for group in range(5):
    for group2 in range(5):
        if group2 > group:
            for gene in [atsurv, la, lb, her2, bl][group]:
                if gene in [atsurv, la, lb, her2, bl][group2]:
                    print(groups[group], groups[group2], gene)
# Out:
# atsurv la BOP1
# atsurv la CBX2
# atsurv la CDC20
# atsurv la CDYL2
# atsurv la DNMT3B
# atsurv la DTL
# atsurv la EZH2
# atsurv la FGD3
# atsurv la KDM4B
# atsurv la MLPH
# atsurv la ORC1
# atsurv la POC1A
# atsurv la SUV39H2
# atsurv la TCF19
# atsurv la TLE3
# atsurv la UHRF1
# atsurv la WDHD1
# atsurv la CBX7
# atsurv la FYCO1
# atsurv la MYRIP
# atsurv la WDR86
# atsurv lb DTL
# atsurv lb MLPH
# atsurv lb PLEKHF2
# atsurv lb UHRF1
# atsurv lb PLEKHF1
# atsurv lb TLE4
# atsurv her2 CBX2
# atsurv her2 CDC20
# atsurv her2 DNMT3B
# atsurv her2 FGD1
# atsurv her2 FGD3
# atsurv her2 KDM4B
# atsurv her2 ORC1
# atsurv her2 TLE3
# atsurv her2 CBX7
# atsurv her2 EZH1
# atsurv her2 MYRIP
# atsurv her2 PRDM11
# atsurv her2 TLE1
# atsurv her2 WDR27
# atsurv bl ANTKMT
# atsurv bl BOP1
# atsurv bl CBX2
# atsurv bl CBX4
# atsurv bl CDC20
# atsurv bl CDYL2
# atsurv bl DNMT3A
# atsurv bl DNMT3B
# atsurv bl EZH2
# atsurv bl FGD1
# atsurv bl FGD3
# atsurv bl GSTCD
# atsurv bl HDGF
# atsurv bl JMJD4
# atsurv bl KDM4B
# atsurv bl MLPH
# atsurv bl ORC1
# atsurv bl PLEKHF2
# atsurv bl SMYD3
# atsurv bl SP140
# atsurv bl SUV39H2
# atsurv bl TCF19
# atsurv bl TLE3
# atsurv bl UHRF1
# atsurv bl WDR24
# atsurv bl WDR4
# atsurv bl WDR90
# atsurv bl ZFPM1
# atsurv bl ARID4A
# atsurv bl CBX7
# atsurv bl DMXL1
# atsurv bl FYCO1
# atsurv bl PLEKHF1
# atsurv bl SETD7
# atsurv bl TLE1
# atsurv bl TLE4
# la lb DTL
# la lb MLPH
# la lb UHRF1
# la her2 CBX2
# la her2 CDC20
# la her2 DNMT3B
# la her2 FGD3
# la her2 KDM4B
# la her2 ORC1
# la her2 TLE3
# la her2 CBX7
# la her2 MYRIP
# la her2 DNAI4
# la her2 ELP2
# la her2 JADE2
# la her2 SYTL4
# la her2 ZFYVE28
# la bl BOP1
# la bl CBX2
# la bl CDC20
# la bl CDYL2
# la bl DNMT3B
# la bl EZH2
# la bl FGD3
# la bl KDM4B
# la bl MLPH
# la bl ORC1
# la bl SUV39H2
# la bl TCF19
# la bl TLE3
# la bl UHRF1
# la bl CBX7
# la bl FYCO1
# la bl DNAI4
# la bl ELP2
# la bl JADE2
# la bl KCTD3
# la bl RPH3AL
# la bl SYTL2
# la bl SYTL4
# la bl ZFYVE28
# la bl CHD7
# la bl HR
# la bl LBR
# la bl SCML2
# la bl TAF5
# la bl WDR62
# lb bl MLPH
# lb bl PLEKHF2
# lb bl UHRF1
# lb bl PLEKHF1
# lb bl TLE4
# her2 bl CBX2
# her2 bl CDC20
# her2 bl DNMT3B
# her2 bl FGD1
# her2 bl FGD3
# her2 bl KDM4B
# her2 bl ORC1
# her2 bl TLE3
# her2 bl CBX7
# her2 bl TLE1
# her2 bl DNAI4
# her2 bl ELP2
# her2 bl JADE2
# her2 bl SYTL4
# her2 bl ZFYVE28

# %% [markdown]
# # Super analysis

# %%
for i in anova_results:
    print(anova_results[i])
# Out:
# 0       ANTKMT
# 1         BOP1
# 2        BRAT1
# 3         BUB3
# 4         CBX2
# 5         CBX3
# 6         CBX4
# 7         CBX8
# 8        CDC20
# 9        CDYL2
# 10        CHD4
# 11       CKAP5
# 12        COPA
# 13       COPB2
# 14       CORO7
# 15       DNMT1
# 16      DNMT3A
# 17      DNMT3B
# 18        DOHH
# 19         DTL
# 20     EEF2KMT
# 21       EHMT2
# 22       EIPR1
# 23        EZH2
# 24       FBXW9
# 25        FGD1
# 26        FGD3
# 27        FGD6
# 28       GNB1L
# 29       GSTCD
# 30        HDGF
# 31       JADE3
# 32       JMJD4
# 33       KDM4B
# 34       KDM5B
# 35       KMT5C
# 36       LRWD1
# 37        MLPH
# 38       MROH1
# 39        NSD2
# 40        ORC1
# 41     PLEKHF2
# 42       POC1A
# 43       PYGO2
# 44       RBBP7
# 45       RIOX1
# 46       SEC13
# 47       SMYD3
# 48       SP140
# 49     SUV39H1
# 50     SUV39H2
# 51        TBL2
# 52        TBL3
# 53       TCF19
# 54       TDRKH
# 55       THOC3
# 56       THOC6
# 57        TLE3
# 58       TRAF7
# 59      TTLL12
# 60       UHRF1
# 61       UTP18
# 62       WDHD1
# 63       WDR18
# 64       WDR24
# 65        WDR4
# 66       WDR54
# 67       WDR83
# 68       WDR90
# 69       ZFPM1
# 70      ARID4A
# 71        CBX6
# 72        CBX7
# 73        CHD9
# 74       DMXL1
# 75        EEA1
# 76        EZH1
# 77       FBXW7
# 78        FGD4
# 79        FGD5
# 80       FYCO1
# 81       HERC1
# 82        ING3
# 83       JADE1
# 84       KMT2A
# 85       MECOM
# 86       MTMR3
# 87       MYRIP
# 88       PHF10
# 89     PIKFYVE
# 90     PLEKHF1
# 91      PRDM11
# 92       PRDM5
# 93       PRDM8
# 94       PYGO1
# 95        RERE
# 96       SETD7
# 97      SETDB2
# 98       SHPRH
# 99       SMYD4
# 100       TLE1
# 101       TLE2
# 102       TLE4
# 103      WDFY2
# 104      WDR17
# 105      WDR27
# 106      WDR86
# 107       WSB1
# 108      ZFPM2
# 109     ZFYVE9
# 110      CORO6
# 111      DNAI4
# 112       ELP2
# 113      JADE2
# 114      KCTD3
# 115     RPH3AL
# 116      SYTL2
# 117      SYTL4
# 118      SYTL5
# 119      WDR93
# 120    ZFYVE28
# 121       CHD7
# 122         HR
# 123        LBR
# 124      SCML2
# 125       TAF5
# 126      WDR62
# 127      DNAI1
# 128      MORC4
# 129      TDRD1
# 130       NSD3
# 131      WDR35
# 132      KDM4D
# 133       MSH6
# 134       MSL3
# 135      PHF19
# 136      PSIP1
# 137      SMYD2
# 138      TCF20
# 139      TEX10
# 140      WDR43
# 141      BAZ2A
# 142    BCDIN3D
# 143       CHD1
# 144       CHD6
# 145      DCAF5
# 146    ETFBKMT
# 147      JMJD8
# 148      KAT6B
# 149       KDM8
# 150    METTL15
# 151     N6AMT1
# 152      PAAF1
# 153       PCLO
# 154       PEX7
# 155      PHF12
# 156       PHF7
# 157      STRN3
# 158       UBR7
# 159      WDR25
# 160      WDR31
# 161     ZFYVE1
# 162    ZFYVE16
# Name: Unnamed: 0, dtype: object
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0
# 10     1.0
# 11     1.0
# 12     1.0
# 13     1.0
# 14     1.0
# 15     1.0
# 16     1.0
# 17     1.0
# 18     1.0
# 19     1.0
# 20     1.0
# 21     1.0
# 22     1.0
# 23     1.0
# 24     1.0
# 25     1.0
# 26     1.0
# 27     1.0
# 28     1.0
# 29     1.0
# 30     1.0
# 31     1.0
# 32     1.0
# 33     1.0
# 34     1.0
# 35     1.0
# 36     1.0
# 37     1.0
# 38     1.0
# 39     1.0
# 40     1.0
# 41     1.0
# 42     1.0
# 43     1.0
# 44     1.0
# 45     1.0
# 46     1.0
# 47     1.0
# 48     1.0
# 49     1.0
# 50     1.0
# 51     1.0
# 52     1.0
# 53     1.0
# 54     1.0
# 55     1.0
# 56     1.0
# 57     1.0
# 58     1.0
# 59     1.0
# 60     1.0
# 61     1.0
# 62     1.0
# 63     1.0
# 64     1.0
# 65     1.0
# 66     1.0
# 67     1.0
# 68     1.0
# 69     1.0
# 70    -1.0
# 71    -1.0
# 72    -1.0
# 73    -1.0
# 74    -1.0
# 75    -1.0
# 76    -1.0
# 77    -1.0
# 78    -1.0
# 79    -1.0
# 80    -1.0
# 81    -1.0
# 82    -1.0
# 83    -1.0
# 84    -1.0
# 85    -1.0
# 86    -1.0
# 87    -1.0
# 88    -1.0
# 89    -1.0
# 90    -1.0
# 91    -1.0
# 92    -1.0
# 93    -1.0
# 94    -1.0
# 95    -1.0
# 96    -1.0
# 97    -1.0
# 98    -1.0
# 99    -1.0
# 100   -1.0
# 101   -1.0
# 102   -1.0
# 103   -1.0
# 104   -1.0
# 105   -1.0
# 106   -1.0
# 107   -1.0
# 108   -1.0
# 109   -1.0
# 110    NaN
# 111    NaN
# 112    NaN
# 113    NaN
# 114    NaN
# 115    NaN
# 116    NaN
# 117    NaN
# 118    NaN
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
# 123    NaN
# 124    NaN
# 125    NaN
# 126    NaN
# 127    NaN
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: All-tumours, dtype: float64
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4     -1.0
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     NaN
# 73     NaN
# 74     NaN
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# 79     NaN
# 80     NaN
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     NaN
# 88     NaN
# 89     NaN
# 90     NaN
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    NaN
# 112    NaN
# 113    NaN
# 114    NaN
# 115    NaN
# 116    NaN
# 117    NaN
# 118    NaN
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
# 123    NaN
# 124    NaN
# 125    NaN
# 126    NaN
# 127    NaN
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: Stage-I, dtype: float64
# 0      NaN
# 1     -1.0
# 2      NaN
# 3      NaN
# 4     -1.0
# 5      NaN
# 6      NaN
# 7      NaN
# 8     -1.0
# 9      1.0
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17    -1.0
# 18     NaN
# 19    -1.0
# 20     NaN
# 21     NaN
# 22     NaN
# 23    -1.0
# 24     NaN
# 25     NaN
# 26     1.0
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     1.0
# 34     NaN
# 35     NaN
# 36     NaN
# 37     1.0
# 38     NaN
# 39     NaN
# 40    -1.0
# 41     NaN
# 42    -1.0
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50    -1.0
# 51     NaN
# 52     NaN
# 53    -1.0
# 54     NaN
# 55     NaN
# 56     NaN
# 57     1.0
# 58     NaN
# 59     NaN
# 60    -1.0
# 61     NaN
# 62    -1.0
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     1.0
# 73     NaN
# 74     NaN
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# 79     NaN
# 80     1.0
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     1.0
# 88     NaN
# 89     NaN
# 90     NaN
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    1.0
# 107    NaN
# 108    NaN
# 109    NaN
# 110    1.0
# 111    1.0
# 112    1.0
# 113    1.0
# 114    1.0
# 115    1.0
# 116    1.0
# 117    1.0
# 118    1.0
# 119    1.0
# 120    1.0
# 121   -1.0
# 122   -1.0
# 123   -1.0
# 124   -1.0
# 125   -1.0
# 126   -1.0
# 127    NaN
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: Luminal-A, dtype: float64
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     1.0
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     1.0
# 38     NaN
# 39     NaN
# 40     NaN
# 41     1.0
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     1.0
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     NaN
# 73     NaN
# 74     NaN
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# 79     NaN
# 80     NaN
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     NaN
# 88     NaN
# 89     NaN
# 90    -1.0
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102   -1.0
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    NaN
# 112    NaN
# 113    NaN
# 114    NaN
# 115    NaN
# 116    NaN
# 117    NaN
# 118    NaN
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
# 123    NaN
# 124    NaN
# 125    NaN
# 126    NaN
# 127    1.0
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: Luminal-B, dtype: float64
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      1.0
# 5      NaN
# 6      NaN
# 7      NaN
# 8      1.0
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     1.0
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25    -1.0
# 26    -1.0
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33    -1.0
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     1.0
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57    -1.0
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72    -1.0
# 73     NaN
# 74     NaN
# 75     NaN
# 76    -1.0
# 77     NaN
# 78     NaN
# 79     NaN
# 80     NaN
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87    -1.0
# 88     NaN
# 89     NaN
# 90     NaN
# 91    -1.0
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    1.0
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105   -1.0
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111   -1.0
# 112   -1.0
# 113   -1.0
# 114    NaN
# 115    NaN
# 116    NaN
# 117   -1.0
# 118    NaN
# 119    NaN
# 120   -1.0
# 121    NaN
# 122    NaN
# 123    NaN
# 124    NaN
# 125    NaN
# 126    NaN
# 127    NaN
# 128    1.0
# 129    1.0
# 130   -1.0
# 131   -1.0
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: HER2-enriched, dtype: float64
# 0     -1.0
# 1      1.0
# 2      NaN
# 3      NaN
# 4      1.0
# 5      NaN
# 6     -1.0
# 7      NaN
# 8      1.0
# 9     -1.0
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     1.0
# 17     1.0
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     1.0
# 24     NaN
# 25     1.0
# 26    -1.0
# 27     NaN
# 28     NaN
# 29    -1.0
# 30     1.0
# 31     NaN
# 32     1.0
# 33    -1.0
# 34     NaN
# 35     NaN
# 36     NaN
# 37    -1.0
# 38     NaN
# 39     NaN
# 40     1.0
# 41    -1.0
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47    -1.0
# 48     1.0
# 49     NaN
# 50     1.0
# 51     NaN
# 52     NaN
# 53     1.0
# 54     NaN
# 55     NaN
# 56     NaN
# 57    -1.0
# 58     NaN
# 59     NaN
# 60     1.0
# 61     NaN
# 62     NaN
# 63     NaN
# 64    -1.0
# 65     1.0
# 66     NaN
# 67     NaN
# 68    -1.0
# 69    -1.0
# 70    -1.0
# 71     NaN
# 72    -1.0
# 73     NaN
# 74    -1.0
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# 79     NaN
# 80    -1.0
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     NaN
# 88     NaN
# 89     NaN
# 90     1.0
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96    -1.0
# 97     NaN
# 98     NaN
# 99     NaN
# 100    1.0
# 101    NaN
# 102    1.0
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111   -1.0
# 112   -1.0
# 113   -1.0
# 114   -1.0
# 115   -1.0
# 116   -1.0
# 117   -1.0
# 118    NaN
# 119    NaN
# 120   -1.0
# 121    1.0
# 122    1.0
# 123    1.0
# 124    1.0
# 125    1.0
# 126    1.0
# 127    NaN
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    1.0
# 133    1.0
# 134    1.0
# 135    1.0
# 136    1.0
# 137    1.0
# 138    1.0
# 139    1.0
# 140    1.0
# 141   -1.0
# 142   -1.0
# 143   -1.0
# 144   -1.0
# 145   -1.0
# 146   -1.0
# 147   -1.0
# 148   -1.0
# 149   -1.0
# 150   -1.0
# 151   -1.0
# 152   -1.0
# 153   -1.0
# 154   -1.0
# 155   -1.0
# 156   -1.0
# 157   -1.0
# 158   -1.0
# 159   -1.0
# 160   -1.0
# 161   -1.0
# 162   -1.0
# Name: Basal-like, dtype: float64
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     NaN
# 73     NaN
# 74     NaN
# 75     NaN
# 76     NaN
# 77     NaN
# 78     NaN
# 79     NaN
# 80     NaN
# 81     NaN
# 82     NaN
# 83     NaN
# 84     NaN
# 85     NaN
# 86     NaN
# 87     NaN
# 88     NaN
# 89     NaN
# 90     NaN
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96     NaN
# 97     NaN
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110    NaN
# 111    NaN
# 112    NaN
# 113    NaN
# 114    NaN
# 115    NaN
# 116    NaN
# 117    NaN
# 118    1.0
# 119    NaN
# 120    NaN
# 121    NaN
# 122    NaN
# 123    NaN
# 124    NaN
# 125    NaN
# 126    NaN
# 127    NaN
# 128    NaN
# 129    NaN
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137    NaN
# 138    NaN
# 139    NaN
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154    NaN
# 155    NaN
# 156    NaN
# 157    NaN
# 158    NaN
# 159    NaN
# 160    NaN
# 161    NaN
# 162    NaN
# Name: N1, dtype: float64
